# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13132\1511576176.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
with open('smartprix.html','r', encoding='utf-8') as f:
    html =f.read()

# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Using cached lxml-5.2.2-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Using cached lxml-5.2.2-cp311-cp311-win_amd64.whl (3.8 MB)
# Installing collected packages: lxml
# Successfully installed lxml-5.2.2
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
soup= BeautifulSoup(html,'html.parser')
#soup= BeautifulSoup(html,'lxml')

# %%
soup.prettify()
# Out:
# '<html class="way-item-finder" lang="en" style="--window-width: 1540;">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width" name="viewport"/>\n  <title>\n   Mobile Phones In Stock | Smartprix\n  </title>\n  <link href="/sm-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>\n  <meta content="#4692F0" name="theme-color"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="171761809591603" property="fb:app_id"/>\n  <link href="https://www.smartprix.com/mobiles/exclude_out_of_stock-exclude_upcoming-stock" rel="canonical"/>\n  <meta content="Smartprix" property="og:site_name"/>\n  <meta content="@smartprix" name="twitter:site"/>\n  <meta content="@smartprix" name="twitter:creator"/>\n  <meta content="summary" name="twitter:card"/>\n  <link href="/smartprix_search.xml" rel="search" title="Smartprix Search: Find the best price" type="application/opensearchdescription+xml"/>\n  <script type="application/ld+json">\n   {"@type":"Organization","@context":"http://schema.org/","@id":"https://www.smartprix.com#organization","name":"Smartprix","url":"https://www.smartprix.com","sameAs":["https://www.facebook.com/smartprix","https://www.instagram.com/smartprix/","https://www.linkedin.com/company/smartprix/","https://plus.google.com/102248368379090638322","https://www.pinterest.com/smartprixcom/","https://twitter.com/smartprix","https://www.youtube.com/channel/UCvkQPgMQX_C1i9JnDZmOY2Q","https://t.me/Smartprix_Deals"],"logo":"https://www.smartprix.com/smartprix.png"}\n  </script>\n  <script type="application/ld+json">\n   {"@type":"Website","@context":"http://schema.org/","@id":"https://www.smartprix.com#website","url":"https://www.smartprix.com","potentialAction":{"@type":"SearchAction","target":"https://www.smartprix.com/products/?q={search_term}","query-input":"required name=search_term"}}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Mobile Phones","item":"https://www.smartprix.com/mobiles"},{"@type":"ListItem","position":2,"name":"Mobile Phones In Stock","item":"https://www.smartprix.com/mobiles/exclude_out_of_stock-stock"}]}\n  </script>\n  <script type="application/ld+json">\n   {"@context":"http://schema.org/","@type":"ItemList","itemListElement":[{"@type":"ListItem","additionalType":"Product","position":1,"name":"Infinix GT 20 Pro","url":"https://www.smartprix.com/mobiles/infinix-gt-20-pro-ppd1vmhyefpn","image":["https://cdn1.smartprix.com/rx-ieG5UTKge-w1200-h1200/eG5UTKge.webp"]},{"@type":"ListItem","additionalType":"Product","position":2,"name":"Vivo T3x 5G","url":"https://www.smartprix.com/mobiles/vivo-t3x-5g-ppd16m90nezl","image":["https://cdn1.smartprix.com/rx-ibpdbuWdX-w1200-h1200/bpdbuWdX.webp"]},{"@type":"ListItem","additionalType":"Product","position":3,"name":"iQOO Z9x","url":"https://www.smartprix.com/mobiles/iqoo-z9x-ppd1173nbq54","image":["https://cdn1.smartprix.com/rx-idTJ8yZLK-w1200-h1200/dTJ8yZLK.webp"]},{"@type":"ListItem","additionalType":"Product","position":4,"name":"Samsung Galaxy S25 Ultra","url":"https://www.smartprix.com/mobiles/samsung-galaxy-s25-ultra-ppd1p8z4fzt4","image":["https://cdn1.smartprix.com/rx-irL2QXDwz-w1200-h1200/rL2QXDwz.webp"]},{"@type":"ListItem","additionalType":"Product","position":5,"name":"OnePlus Nord CE 4 5G","url":"https://www.smartprix.com/mobiles/oneplus-nord-ce-4-5g-ppd1ayfp2rd8","image":["https://cdn1.smartprix.com/rx-iJIRhERgV-w1200-h1200/JIRhERgV.webp"]},{"@type":"ListItem","additionalType":"Product","position":6,"name":"Vivo V30e 5G","url":"https://www.smartprix.com/mobiles/vivo-v30e-ppd1m8y13f7f","image":["https://cdn1.smartprix.com/rx-iKMGjnQpU-w1200-h1200/KMGjnQpU.webp"]},{"@type":"ListItem","additionalType":"Product","position":7,"name":"Motorola Edge 50 Pro 5G","url":"https://www.smartprix.com/mobiles/motorola-edge-50-pro-ppd1jpg2bc ...

# %%
containers=(soup.find_all('div',{'class':"sm-product has-tag has-features has-actions"}))

# %%
# name=[]
# price=[]
# specs=[]

# # for i in containers:
# #     name.append(i.find('h2').text)
# #     price.append(i.find('span').text)
# #     #print(i.find('div',{'class':"score rank-1-bg"}).find('b').text)
# #     score_div = i.find('div', {'class': "score rank-1-bg"})
# #     if score_div:
# #         specs.append(score_div.find('b').text)
# #     else:
# #         specs.append(np.nan)
# for i in containers:
#     name.append(i.find('h2').text)
#     price.append(i.find('span').text)
#     score_div_1 = i.find('div', {'class': "score rank-1-bg"})
#     score_div_2 = i.find('div', {'class': "score rank-2-bg"})
#     score_div_3 = i.find('div', {'class': "score rank-5-bg"})
#     score_div_4 = i.find('div', {'class': "score rank-4-bg"})
#     score_div_5 = i.find('div', {'class': "score rank-3-bg"})

    
    
#     if score_div_1:
#         specs.append(score_div_1.find('b').text)
#     elif score_div_2:
#         specs.append(score_div_2.find('b').text)
#     elif score_div_3:
#         specs.append(score_div_3.find('b').text)
#     elif score_div_4:
#         specs.append(score_div_4.find('b').text)
#     elif score_div_5:
#         specs.append(score_div_5.find('b').text)
#     else:
#         specs.append(np.nan)

# %%
names=[]
prices=[]
rating=[]
sim=[]
processor=[]
ram=[]
battery=[]
display=[]
camera=[]
card=[]
os=[]

for i in containers:
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span', {'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        score_classes = ["score rank-1-bg", "score rank-2-bg", "score rank-3-bg", "score rank-4-bg", "score rank-5-bg"]
        rating_found = False
        for score_class in score_classes:
            score_div = i.find('div', {'class': score_class})
            if score_div:
                rating.append(score_div.find('b').text)
                rating_found = True
                break
        if not rating_found:
            rating.append(np.nan)
    except:
        rating.append(np.nan)
    x= i.find('ul', {'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(os)
# Out:
# 1020

# %%
df= pd.DataFrame({
    "model":name,
    "price":price,
    "rating":rating,
    "sim":sim,
    "processor":processor,
    "ram":ram,
    "battery":"battery",
    "display":display,
    "camera":camera,
    "card":card,
    "os":os
})

# %%
df
# Out:
#                         model    price rating
# 0                 Vivo T3x 5G  ₹13,499     75
# 1        OnePlus Nord CE 4 5G  ₹24,490     83
# 2                Vivo V30e 5G  ₹27,999     86
# 3     Motorola Edge 50 Pro 5G  ₹31,999     87
# 4              OnePlus 11R 5G  ₹29,999     85
# ...                       ...      ...    ...
# 1015          Snexian Bold 15   ₹1,999     15
# 1016         Snexian Guru 912     ₹999     14
# 1017      Snexian Rock R4 New     ₹999     10
# 1018          Snexian Rock R5     ₹999     10
# 1019           GFive Rose 310     ₹649     11
#
# [1020 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# model     0
# price     0
# rating    0
# dtype: int64
